# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.randint(0,100,10),columns=['sales'])
df.head()
# Out:
#    sales
# 0      9
# 1     70
# 2     89
# 3      4
# 4     12

# %%
df
# Out:
#    sales
# 0      9
# 1     70
# 2     89
# 3      4
# 4     12
# 5     23
# 6     25
# 7     98
# 8     63
# 9     33

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -------------------- ------------------- 4.2/8.1 MB 22.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 21.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 27.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 26.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))

# %%
plt.plot(['sales'])

# %%
plt.plot(df['sales'],marker='o',color="#40DFED",markerfacecolor='w',
         markeredgecolor='b',markeredgewidth=1,linewidth=4,alpha=0.6)

# %%
plt.figure(figsize=(15,5))
plt.plot(df['sales'],marker='o',color="#40DFED",markerfacecolor='w',
         markeredgecolor='b',markeredgewidth=1,linewidth=0,alpha=0.6)

# %%
plt.figure(figsize=(15,5))
plt.plot(df['sales'],marker='o',color="#40DFED",markerfacecolor='w',
         markeredgecolor='b',markeredgewidth=1,linewidth=5,alpha=0.6)
plt.xlabel("Index")
plt.ylabel("Sales")
plt.title("Sales vs Index")
# Out:
# Text(0.5, 1.0, 'Sales vs Index')

# %%
df=pd.DataFrame(np.random.randint(0,10,(10,5)),columns="A B C D E".split())
df
# Out:
#    A  B  C  D  E
# 0  3  7  7  8  0
# 1  5  7  8  0  1
# 2  2  4  1  7  1
# 3  0  1  9  6  3
# 4  0  1  2  0  1
# 5  9  5  7  3  3
# 6  8  5  7  1  1
# 7  1  9  6  6  5
# 8  1  7  8  8  0
# 9  8  2  2  2  6

# %%
plt.subplot(2,2,1)
plt.plot(df['A'],color='r')
plt.subplot(2,2,2)
plt.plot(df['B'],color='b')
plt.subplot(2,2,3)
plt.plot(df['C'],color='black')
plt.subplot(2,2,4)
plt.plot(df['D'])
plt.savefig("sample.png")

# %%
plt.subplot(2,3,1)
plt.plot(df['A'],color='r')
plt.subplot(2,3,2)
plt.plot(df['B'],color='b')
plt.subplot(2,3,3)
plt.plot(df['C'],color='black')
plt.subplot(2,3,4)
plt.plot(df['D'])
plt.savefig("sample.png")

# %%
plt.subplot(1,4,1)
plt.plot(df['A'],color='r')
plt.subplot(1,4,2)
plt.plot(df['B'],color='b')
plt.subplot(1,4,3)
plt.plot(df['C'],color='black')
plt.subplot(1,4,4)
plt.plot(df['D'])
plt.savefig("sample.png")

# %%
plt.subplot(2,2,1)
plt.plot(df['A'],color='r')
