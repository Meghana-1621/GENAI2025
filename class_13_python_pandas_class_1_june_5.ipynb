# %%
import pandas as pd
import numpy as np

# %%
pd.DataFrame([1,2,3],columns=['names'],index=[7,8,9])
# Out:
#    names
# 7      1
# 8      2
# 9      3

# %%
df=pd.DataFrame(np.random.randint(0,100,(3,3)),columns="A B C".split(),index="P Q R ".split())

# %%
df
# Out:
#     A   B   C
# P  48  31  64
# Q  99  78   7
# R  89  70  71

# %%
df=pd.DataFrame(np.random.randint(0,100,(6,6)),columns="A B C D E F".split(),index="P Q R S T U".split())

# %%
df
# Out:
#     A   B   C   D   E   F
# P  20  36  14  39  22  62
# Q   9  44  55  91  81  66
# R  86  33  96   7  11  91
# S  42  57  75  30  20  46
# T  98   4  59  49  31  72
# U  93  70  39  13  51  13

# %%
df=pd.DataFrame(np.random.randint(0,100,(9,6)))

# %%
data=[]
for i in range(1,10):
  data.append("student"+str(i))

# %%
data
# Out:
# ['student1',
#  'student2',
#  'student3',
#  'student4',
#  'student5',
#  'student6',
#  'student7',
#  'student8',
#  'student9']

# %%
df.index=data

# %%
df
# Out:
#             0   1   2   3   4
# student1   32  39   6  63  11
# student2   24   6  46  38   0
# student3   95  65  20   0  83
# student4   98  27  90  48   8
# student5   78  65   7  43  87
# student6   54  98  75  46   2
# student7   20  79  16  15  78
# student8   84  78  40  21   9
# student9   15  91  19  76  57
# student10  45  37  34  15  90

# %%
data=[]
for i in range(1,5):
  data.append("subject"+str(i))

# %%
df.columns=data

# %%
df
# Out:
#     0   1   2   3   4   5
# 0  17  48  72  36   1  88
# 1  73  11  94  48  44  72
# 2  30  77  68  75  19  88
# 3  94  99   7  40  36  23
# 4  99  81  42  72  88  39
# 5  78  60  37  11  18  20
# 6  54  29   0  99  91  41
# 7  43  49  44   4  53  10
# 8   4  18  59   6  82  58

# %%
df.shape
# Out:
# (9, 6)

# %%
df.values
# Out:
# array([[17, 48, 72, 36,  1, 88],
#        [73, 11, 94, 48, 44, 72],
#        [30, 77, 68, 75, 19, 88],
#        [94, 99,  7, 40, 36, 23],
#        [99, 81, 42, 72, 88, 39],
#        [78, 60, 37, 11, 18, 20],
#        [54, 29,  0, 99, 91, 41],
#        [43, 49, 44,  4, 53, 10],
#        [ 4, 18, 59,  6, 82, 58]])

# %%
df.iloc[:3,-3:]
# Out:
#     3   4   5
# 0  36   1  88
# 1  48  44  72
# 2  75  19  88

# %%
df.iloc[5,5]
# Out:
# np.int64(20)

# %%
df
# Out:
#     0   1   2   3   4   5
# 0  17  48  72  36   1  88
# 1  73  11  94  48  44  72
# 2  30  77  68  75  19  88
# 3  94  99   7  40  36  23
# 4  99  81  42  72  88  39
# 5  78  60  37  11  18  20
# 6  54  29   0  99  91  41
# 7  43  49  44   4  53  10
# 8   4  18  59   6  82  58

# %%
df.iloc[0:4,0:4]
# Out:
#     0   1   2   3
# 0  17  48  72  36
# 1  73  11  94  48
# 2  30  77  68  75
# 3  94  99   7  40

# %%
df=pd.read_excel('/Sample - Superstore.xls')

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df[df['Segment']=='Consumer']
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2020-152156 2020-11-08 2020-11-11    Second Class
# 1          2  CA-2020-152156 2020-11-08 2020-11-11    Second Class
# 3          4  US-2019-108966 2019-10-11 2019-10-18  Standard Class
# 4          5  US-2019-108966 2019-10-11 2019-10-18  Standard Class
# 5          6  CA-2018-115812 2018-06-09 2018-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2018-110422 2018-01-21 2018-01-23    Second Class
# 9990    9991  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9991    9992  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9992    9993  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9993    9994  CA-2021-119914 2021-05-04 2021-05-09    Second Class
#
#      Customer ID     Customer Name   Segment Country/Region             City  \
# 0       CG-12520       Claire Gute  Consumer  United States        Henderson
# ...

# %%
data=np.random.randint(0,10,10)

# %%
data
# Out:
# array([8, 9, 2, 1, 4, 8, 9, 2, 9, 4])

# %%
data[data<5]
# Out:
# array([2, 1, 4, 2, 4])

# %%
df[(df['Region']=='West') & (df['Category']=='Office Supplies')]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2          3  CA-2020-138688 2020-06-12 2020-06-16    Second Class
# 6          7  CA-2018-115812 2018-06-09 2018-06-14  Standard Class
# 8          9  CA-2018-115812 2018-06-09 2018-06-14  Standard Class
# 9         10  CA-2018-115812 2018-06-09 2018-06-14  Standard Class
# 13        14  CA-2020-161389 2020-12-05 2020-12-10  Standard Class
# ...      ...             ...        ...        ...             ...
# 9977    9978  US-2020-103674 2020-12-06 2020-12-10  Standard Class
# 9978    9979  US-2020-103674 2020-12-06 2020-12-10  Standard Class
# 9979    9980  US-2020-103674 2020-12-06 2020-12-10  Standard Class
# 9992    9993  CA-2021-121258 2021-02-26 2021-03-03  Standard Class
# 9993    9994  CA-2021-119914 2021-05-04 2021-05-09    Second Class
#
#      Customer ID    Customer Name      Segment Country/Region         City  \
# 2       DV-13045  Darrin Van Huff    Corporate  United States  Los Angeles
# ...

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State                     object
# Postal Code              float64
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %%
df.select_dtypes(include='float').mean()
# Out:
# Postal Code    55245.233297
# Sales            229.858001
# Discount           0.156203
# Profit            28.656896
# dtype: float64

# %%
df.select_dtypes(include='float').median()
# Out:
# Postal Code    57103.0000
# Sales             54.4900
# Discount           0.2000
# Profit             8.6665
# dtype: float64

# %%
df.select_dtypes(include='float').min()
# Out:
# Postal Code    1040.000
# Sales             0.444
# Discount          0.000
# Profit        -6599.978
# dtype: float64

# %%
df.select_dtypes(include='float').max()
# Out:
# Postal Code    99301.000
# Sales          22638.480
# Discount           0.800
# Profit          8399.976
# dtype: float64

# %%
df.select_dtypes(include='float').std()
# Out:
# Postal Code    32038.715955
# Sales            623.245101
# Discount           0.206452
# Profit           234.260108
# dtype: float64

# %%
df.select_dtypes(include='float').var()
# Out:
# Postal Code    1.026479e+09
# Sales          3.884345e+05
# Discount       4.262242e-02
# Profit         5.487780e+04
# dtype: float64

# %%
df.select_dtypes(include='float').quantile(0.50)
# Out:
# Postal Code    57103.0000
# Sales             54.4900
# Discount           0.2000
# Profit             8.6665
# Name: 0.5, dtype: float64

# %%
df.select_dtypes(include='float').quantile(0.75)
# Out:
# Postal Code    90008.000
# Sales            209.940
# Discount           0.200
# Profit            29.364
# Name: 0.75, dtype: float64

# %%
df.select_dtypes(include='float').quantile(0.25)
# Out:
# Postal Code    23223.00000
# Sales             17.28000
# Discount           0.00000
# Profit             1.72875
# Name: 0.25, dtype: float64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.loc[:,["Sales","Region"]].groupby("Region").sum()
# Out:
#                Sales
# Region
# Central  501239.8908
# East     678781.2400
# South    391721.9050
# West     725457.8245

# %%
df.loc[:,["Sales","Region"]].groupby("Region").sum()
# Out:
#                Sales
# Region
# Central  501239.8908
# East     678781.2400
# South    391721.9050
# West     725457.8245

# %%
df.loc[:,["Sales","Region"]].groupby("Region").mean()
# Out:
#               Sales
# Region
# Central  215.772661
# East     238.336110
# South    241.803645
# West     226.493233

# %%
df.loc[:,["Sales","Region"]].groupby("Region").median()
# Out:
#           Sales
# Region
# Central  45.980
# East     54.900
# South    54.594
# West     60.840

# %%
df.shape
# Out:
# (9994, 21)
